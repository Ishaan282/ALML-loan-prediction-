# %% [markdown]
# Sure, here's a brief explanation of each column:
#
# 1. `Loan_ID`: A unique identifier for each loan. This is likely used to track individual loans.
#
# 2. `Gender`: The gender of the person applying for the loan. Typically, this will be male or female.
#
# 3. `Married`: This indicates whether the loan applicant is married. It's usually a binary value (Yes or No).
#
# 4. `Dependents`: The number of people the applicant is financially responsible for (like children or elderly parents).
#
# 5. `Education`: The education level of the loan applicant. This could be categories like high school, bachelor's degree, master's degree, etc.
#
# 6. `Self_Employed`: This indicates whether the loan applicant is self-employed. It's usually a binary value (Yes or No).
#
# 7. `ApplicantIncome`: The income of the loan applicant. This is likely a numerical value.
#
# 8. `CoapplicantIncome`: The income of the co-applicant, if there is one. This is also likely a numerical value.
#
# 9. `LoanAmount`: The amount of loan the applicant is applying for.
#
# 10. `Loan_Amount_Term`: The term over which the loan will be repaid. This is usually in <strong> days </strong>
#
# 11. `Credit_History`: This likely indicates whether the applicant has a history of repaying their loans. It could be a binary value (1 for yes, 0 for no) or a score.
#
# 12. `Property_Area`: The area where the property the loan is being taken for is located. This could be urban, semi-urban, rural, etc.
#
# 13. `Loan_Status`: The status of the loan application. This could be categories like approved, rejected, pending, etc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = pd.read_csv('hi.csv')


numerical_vars = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

sns.pairplot(data[numerical_vars])
